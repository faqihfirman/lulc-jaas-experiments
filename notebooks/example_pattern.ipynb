# %% [markdown]
# # **Super Title untuk Sebuah Bgaian**
#
# penjelasan singkat mengenai bagian ini

# %% [markdown]
# #### **sub title 1**
#
# penjelasan singkat mengenai sub ini

# %%
# CONFIG

'''di taruh di atas cell yang relevan
jika area ini untuk tuning maka ini config hyperparameternya.

pastikan selalu ada config global seed untuk reproducibilty
'''

# %%
# code: buat yang rapih, gunakan variabel ekplisit dan hindari emot

# %% [markdown]
# #### **sub title 2**
#
# penjelasan singkat mengenai sub ini

# %%
# code: # code: buat yang rapih, gunakan variabel ekplisit dan hindari emot

# %% [markdown]
# # **SAVE ARTIFACT**

# %%
#bagian ini harus ada untuk reproducibilty model, taruh di model aja/experiments
